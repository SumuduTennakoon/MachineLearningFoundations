# %% [markdown]
# # Probability and Statistics for Machine Learning
# Sumudu Tennakoon, PhD
#
# To learn more about Python, refeer to the following websites
#
# * Python : www.python.org
# * W3Schools : www.w3schools.com/python
#
# To learn more about the Python packages we explore in this notebook, refeer to the following websites
#
# * NumPy : www.numpy.org
# * Matplotlib : www.matplotlib.org
# * Pandas : https://pandas.pydata.org
# * Scikit-Learn : https://scikit-learn.org/
# * Seaborn: https://seaborn.pydata.org/
# * StatsModel : https://www.statsmodels.org

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Descriptive Statistcis

# %%
scores = np.array([75, 59, 63, 51, 53, 39, 85, 69, 73, 73, 34, 56, 34, 80, 78, 100, 64, 95, 74, 95])
print(F"scores = {scores}")
print(F"type(scores) = {type(scores)}")
# Out:
# scores = [ 75  59  63  51  53  39  85  69  73  73  34  56  34  80  78 100  64  95
#   74  95]
# type(scores) = <class 'numpy.ndarray'>

# %%
# Numpy functions
print(F"mean(scores) = {scores.mean()}")
print(F"min(scores) = {scores.min()}")
print(F"max(scores) = {scores.max()}")
print(F"index of min value = {scores.argmin()}") #array index starts from 0.
print(F"index of max value = {scores.argmax()}")
# Out:
# mean(scores) = 67.5
# min(scores) = 34
# max(scores) = 100
# index of min value = 10
# index of max value = 15

# %% [markdown]
# ## Sorting Data using Numpy Array
# https://numpy.org/doc/stable/reference/generated/numpy.sort.html

# %%
print(F"scores un-sorted = {scores}")
print(F"scores sorted ascending = {np.sort(scores)}")
print(F"indices sorted ascending = {np.argsort(scores)}")
# Out:
# scores un-sorted = [ 75  59  63  51  53  39  85  69  73  73  34  56  34  80  78 100  64  95
#   74  95]
# scores sorted ascending = [ 34  34  39  51  53  56  59  63  64  69  73  73  74  75  78  80  85  95
#   95 100]
# indices sorted ascending = [10 12  5  3  4 11  1  2 16  7  9  8 18  0 14 13  6 17 19 15]

# %%
print(F"cumulative sum ordered = {np.cumsum(np.sort(scores))}")
# Out:
# cumulative sum ordered = [  34   68  107  158  211  267  326  389  453  522  595  668  742  817
#   895  975 1060 1155 1250 1350]

# %% [markdown]
# # Exploaring a Dataset
# ## Load Data

# %%
file_name = 'https://raw.githubusercontent.com/SumuduTennakoon/MLFoundations/main/Datasets/auto_mpg.csv'

# Load CSV File
data = pd.read_csv(file_name)
data.sample(10)
# Out:
#       mpg  cylinders  displacement  ...  modelyear  origin                 car_name
# 300  34.5          4         105.0  ...         79       1     plymouth horizon tc3
# 240  21.5          4         121.0  ...         77       2                 bmw 320i
# 96   18.0          6         225.0  ...         73       1         plymouth valiant
# 184  27.0          4         101.0  ...         76       2             renault 12tl
# 23   26.0          4         121.0  ...         70       2                 bmw 2002
# 148  26.0          4         108.0  ...         74       3                   subaru
# 166  23.0          4         140.0  ...         75       1               ford pinto
# 101  26.0          4          97.0  ...         73       2  volkswagen super beetle
# 67   13.0          8         350.0  ...         72       1     buick lesabre custom
# 257  20.8          6         200.0  ...         78       1           mercury zephyr
#
# [10 rows x 9 columns]

# %%
data.shape
# Out:
# (392, 9)

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  ...  modelyear  origin                   car_name
# 0  18.0          8         307.0  ...         70       1  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...         70       1          buick skylark 320
# 2  18.0          8         318.0  ...         70       1         plymouth satellite
# 3  16.0          8         304.0  ...         70       1              amc rebel sst
# 4  17.0          8         302.0  ...         70       1                ford torino
#
# [5 rows x 9 columns]

# %% [markdown]
# # Descriptive Statistics

# %%
d = data.describe(include='all')
d.transpose()
# Out:
#              count unique             top freq  ...      25%     50%      75%   max
# mpg            392    NaN             NaN  NaN  ...       17   22.75       29  46.6
# cylinders      392    NaN             NaN  NaN  ...        4       4        8     8
# displacement   392    NaN             NaN  NaN  ...      105     151   275.75   455
# horsepower     392    NaN             NaN  NaN  ...       75    93.5      126   230
# weight         392    NaN             NaN  NaN  ...  2225.25  2803.5  3614.75  5140
# acceleration   392    NaN             NaN  NaN  ...   13.775    15.5   17.025  24.8
# modelyear      392    NaN             NaN  NaN  ...       73      76       79    82
# origin         392    NaN             NaN  NaN  ...        1       1        2     3
# car_name       392    301  toyota corolla    5  ...      NaN     NaN      NaN   NaN
#
# [9 rows x 11 columns]

# %%
s = data['weight'].describe()
s
# Out:
# count     392.000000
# mean     2977.584184
# std       849.402560
# min      1613.000000
# 25%      2225.250000
# 50%      2803.500000
# 75%      3614.750000
# max      5140.000000
# Name: weight, dtype: float64

# %%
data.mean()
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# modelyear         75.979592
# origin             1.576531
# dtype: float64

# %%
mean_value = data['weight'].mean()
print(F"mean = {mean_value}")
# Out:
# mean = 2977.5841836734694

# %%
min_value = data['weight'].min()
max_value = data['weight'].max()

print(F"min = {min_value}")
print(F"max = {max_value}")
# Out:
# min = 1613.0
# max = 5140.0

# %%
mean_value = data['weight'].mean()
median_value = data['weight'].median()
stadard_deviation = data['weight'].std()

print(F"mean = {mean_value}")
print(F"median = {median_value}")
print(F"stadard_deviation = {stadard_deviation}")
# Out:
# mean = 2977.5841836734694
# median = 2803.5
# stadard_deviation = 849.4025600429494

# %% [markdown]
# # Histogram

# %%
#data['weight'].hist(bins=10)
#data.plot(y='weight', kind='hist', bins=10)
data['weight'].plot(kind='hist', bins=10)

# %%
#  Kernel Density Estimation (KDE) is a non-parametric way to estimate the probability density function (PDF) of a random variable. 
data['weight'].plot(kind='kde')

# %%
f,ax0 = plt.subplots()
ax1 = ax0.twinx()

data['weight'].plot(kind='hist', bins=10, ax=ax0)
data['weight'].plot(kind='kde', c='red', ax=ax1)

# %%
data['weight'].skew()
# Out:
# 0.5195856740558396

# %% [markdown]
# # Quantilles
# ## Use of Percentiles and Quartiles

# %%
data['weight'].describe()
# Out:
# count     392.000000
# mean     2977.584184
# std       849.402560
# min      1613.000000
# 25%      2225.250000
# 50%      2803.500000
# 75%      3614.750000
# max      5140.000000
# Name: weight, dtype: float64

# %% [markdown]
# ## Box Plot

# %%
data['weight'].plot(kind='box')

# %%
2225 - 1.5*(3614-2225)
# Out:
# 141.5

# %%
3614 + 1.5*(3614-2225)
# Out:
# 5697.5

# %% [markdown]
# ## Percentiles

# %%
# cutomize describe output
data['weight'].describe(percentiles=[0.05, 0.1, 0.25, 0.5, 0.75, 0.9, 0.95])
# Out:
# count     392.000000
# mean     2977.584184
# std       849.402560
# min      1613.000000
# 5%       1931.600000
# 10%      1990.000000
# 25%      2225.250000
# 50%      2803.500000
# 75%      3614.750000
# 90%      4277.600000
# 95%      4464.000000
# max      5140.000000
# Name: weight, dtype: float64

# %%
data['weight'].quantile(0.9)
# Out:
# 4277.6

# %% [markdown]
# # Corrlation

# %%
data.plot(x='weight', y='mpg', kind='scatter')

# %%
# Numpy function
corr = np.corrcoef(data['weight'],data['mpg'])

print(F"correlation coefficient matrix =\n{corr} ")
print(F"corrleation between wight and mpg = {corr[0][1]}")
# Out:
# correlation coefficient matrix =
# [[ 1.         -0.83224421]
#  [-0.83224421  1.        ]]
# corrleation between wight and mpg = -0.8322442148315753

# %%
# Pandas function
data.corr()
# Out:
#                    mpg  cylinders  ...  modelyear    origin
# mpg           1.000000  -0.777618  ...   0.580541  0.565209
# cylinders    -0.777618   1.000000  ...  -0.345647 -0.568932
# displacement -0.805127   0.950823  ...  -0.369855 -0.614535
# horsepower   -0.778427   0.842983  ...  -0.416361 -0.455171
# weight       -0.832244   0.897527  ...  -0.309120 -0.585005
# acceleration  0.423329  -0.504683  ...   0.290316  0.212746
# modelyear     0.580541  -0.345647  ...   1.000000  0.181528
# origin        0.565209  -0.568932  ...   0.181528  1.000000
#
# [8 rows x 8 columns]

# %%
# Seborn Correlogram (will take some time to generate figure)
import seaborn as sns
import matplotlib.pyplot as plt


sns.pairplot(data)
plt.show()

# %% [markdown]
# # Sampling

# %% [markdown]
# ## Random Sample

# %%
data.sample(100)
# Out:
#       mpg  cylinders  ...  origin                         car_name
# 242  43.1          4  ...       2  volkswagen rabbit custom diesel
# 11   14.0          8  ...       1               plymouth 'cuda 340
# 251  20.5          6  ...       1                 chevrolet malibu
# 231  29.0          4  ...       2         volkswagen rabbit custom
# 32   19.0          6  ...       1                      amc gremlin
# ..    ...        ...  ...     ...                              ...
# 236  33.5          4  ...       1                   dodge colt m/m
# 264  30.0          4  ...       1               chevrolet chevette
# 307  41.5          4  ...       2                        vw rabbit
# 13   14.0          8  ...       1          buick estate wagon (sw)
# 196  33.0          4  ...       3                      honda civic
#
# [100 rows x 9 columns]

# %%
P = data
S = data.sample(100)

# %%
P.describe().transpose()
# Out:
#               count         mean         std  ...      50%       75%     max
# mpg           392.0    23.445918    7.805007  ...    22.75    29.000    46.6
# cylinders     392.0     5.471939    1.705783  ...     4.00     8.000     8.0
# displacement  392.0   194.411990  104.644004  ...   151.00   275.750   455.0
# horsepower    392.0   104.469388   38.491160  ...    93.50   126.000   230.0
# weight        392.0  2977.584184  849.402560  ...  2803.50  3614.750  5140.0
# acceleration  392.0    15.541327    2.758864  ...    15.50    17.025    24.8
# modelyear     392.0    75.979592    3.683737  ...    76.00    79.000    82.0
# origin        392.0     1.576531    0.805518  ...     1.00     2.000     3.0
#
# [8 rows x 8 columns]

# %%
S.describe().transpose()
# Out:
#               count      mean         std  ...     50%      75%     max
# mpg           100.0    24.176    7.619792  ...    23.0    30.00    44.6
# cylinders     100.0     5.160    1.612577  ...     4.0     6.00     8.0
# displacement  100.0   176.150   93.927801  ...   140.0   231.25   455.0
# horsepower    100.0    99.990   33.834563  ...    90.0   106.25   225.0
# weight        100.0  2862.590  775.154206  ...  2675.0  3359.75  4997.0
# acceleration  100.0    15.603    2.469959  ...    15.5    17.05    22.2
# modelyear     100.0    76.520    3.571718  ...    77.0    79.00    82.0
# origin        100.0     1.550    0.783349  ...     1.0     2.00     3.0
#
# [8 rows x 8 columns]

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'modelyear', 'origin', 'car_name'],
#       dtype='object')

# %%
X = data[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'modelyear']]

y = data['mpg']

X
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  modelyear
# 0            8         307.0       130.0  3504.0          12.0         70
# 1            8         350.0       165.0  3693.0          11.5         70
# 2            8         318.0       150.0  3436.0          11.0         70
# 3            8         304.0       150.0  3433.0          12.0         70
# 4            8         302.0       140.0  3449.0          10.5         70
# ..         ...           ...         ...     ...           ...        ...
# 387          4         140.0        86.0  2790.0          15.6         82
# 388          4          97.0        52.0  2130.0          24.6         82
# 389          4         135.0        84.0  2295.0          11.6         82
# 390          4         120.0        79.0  2625.0          18.6         82
# 391          4         119.0        82.0  2720.0          19.4         82
#
# [392 rows x 6 columns]

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 387    27.0
# 388    44.0
# 389    32.0
# 390    28.0
# 391    31.0
# Name: mpg, Length: 392, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X.describe().transpose()
# Out:
#               count         mean         std  ...     50%       75%     max
# cylinders     392.0     5.471939    1.705783  ...     4.0     8.000     8.0
# displacement  392.0   194.411990  104.644004  ...   151.0   275.750   455.0
# horsepower    392.0   104.469388   38.491160  ...    93.5   126.000   230.0
# weight        392.0  2977.584184  849.402560  ...  2803.5  3614.750  5140.0
# acceleration  392.0    15.541327    2.758864  ...    15.5    17.025    24.8
# modelyear     392.0    75.979592    3.683737  ...    76.0    79.000    82.0
#
# [6 rows x 8 columns]

# %%
X_train.describe().transpose()
# Out:
#               count         mean         std  ...     50%       75%     max
# cylinders     274.0     5.496350    1.716646  ...     4.0     8.000     8.0
# displacement  274.0   196.744526  104.001305  ...   151.0   302.000   455.0
# horsepower    274.0   104.883212   38.134438  ...    93.5   130.000   230.0
# weight        274.0  2986.485401  838.977833  ...  2818.5  3625.750  5140.0
# acceleration  274.0    15.522263    2.857850  ...    15.4    17.375    24.8
# modelyear     274.0    76.138686    3.619610  ...    76.0    79.000    82.0
#
# [6 rows x 8 columns]

# %%
X_test.describe().transpose()
# Out:
#               count         mean         std  ...     50%       75%     max
# cylinders     118.0     5.415254    1.686174  ...     4.0     6.000     8.0
# displacement  118.0   188.995763  106.369749  ...   140.0   256.000   455.0
# horsepower    118.0   103.508475   39.454777  ...    93.5   115.000   225.0
# weight        118.0  2956.915254  876.415208  ...  2792.5  3587.500  4951.0
# acceleration  118.0    15.585593    2.525131  ...    15.5    16.675    24.6
# modelyear     118.0    75.610169    3.818609  ...    75.0    79.000    82.0
#
# [6 rows x 8 columns]

# %% [markdown]
# # Exercise
#
# Formulate the following system of linear equation in matrix form and solve using numpy arrays.
#
# $$ x+2y+3z=5 $$
# $$ 4x+y+2z=9 $$
# $$ 2x+3y+5z=8 $$

# %%
# complete the lines with #? (4,5,10,13 and 16)
import numpy as np

A=np.array([[1, 2, 3], [4, 1, 2], [2, 3, 5]])
B=np.array([[5], [9], [8]])
#B=np.array([5, 9, 8])

print(F"A=\n{A}")
print(F"b=\n{B}")
# Out:
# A=
# [[1 2 3]
#  [4 1 2]
#  [2 3 5]]
# b=
# [[5]
#  [9]
#  [8]]

# %%
A_inv = np.linalg.inv(A)
print(F"A_inv=\n{A_inv}")

A_det = np.linalg.det(A) 
print(F"A_det=\n{A_det}")

x = np.dot(A_inv, B) 
print(F"x=\n{x}")
# Out:
# A_inv=
# [[ 0.33333333  0.33333333 -0.33333333]
#  [ 5.33333333  0.33333333 -3.33333333]
#  [-3.33333333 -0.33333333  2.33333333]]
# A_det=
# -3.0000000000000036
# x=
# [[ 2.]
#  [ 3.]
#  [-1.]]

# %%
B=np.array([5, 9, 8])
print(F"B = \n{B}")

x = np.dot(A_inv, B) 
print(F"x=\n{x}")
# Out:
# B =
# [5 9 8]
# x=
# [ 2.  3. -1.]

# %% [markdown]
# # Class Survey Question

# %%
A = True
B = False
C = True

# %%
A and B and C
# Out:
# False

# %%
A and not B and C
# Out:
# True

# %%
(A and B) or (A and C)
# Out:
# True

# %% [markdown]
# <hr>
# Last update 2021-09-26 by Sumudu Tennakoon
